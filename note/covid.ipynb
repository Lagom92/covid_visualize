# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os
os.name
if os.name == 'nt':
    plt.rc('font', family='Malgun Gothic')

# %%
from matplotlib import pyplot as plt
 
plt.plot(["쿠팡\n(24)","해외유입\n(376)","조사중\n(392)","교회\n(594)","집단발병\n(678)","그외 기타\n(709)"], [0.9,13.7,14.3,21.6,24.7,25.7])
plt.xlabel('소재\n(명)')
plt.ylabel('비율(%)')
plt.title('서울 소재별 확진자 현황\n(질병관리본부 2020-08-22 집계기준)')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os
os.name
if os.name == 'nt':
    plt.rc('font', family='Malgun Gothic')

# %%
from matplotlib import pyplot as plt
 
plt.plot(["교회\n(1,195)","조사중\n(1,695)","집단발병\n(2,706)","해외유입\n(2,716)","그외 기타\n(3,476)","신천지\n(5,214)"], [7,10,15.9,16,20.2,30.7])
plt.xlabel('소재\n(명)')
plt.ylabel('비율(%)')
plt.title('전국 소재별 확진자 현황\n(질병관리본부 2020-08-22 집계기준)')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os
os.name
if os.name == 'nt':
    plt.rc('font', family='Malgun Gothic')

# %%
from matplotlib import pyplot as plt
 
plt.plot(["교회\n(7)","집단발병\n(190)","제이미주병원\n(196)","조사중\n(745)","그외 기타\n(1,322)","신천지\n(4,512)"], [0.1,2.7,2.8,10.7,19,64.7])
plt.xlabel('소재\n(명)')
plt.ylabel('비율(%)')
plt.title('대구 소재별 확진자 현황\n(질병관리본부 2020-08-22 집계기준)')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os
os.name
if os.name == 'nt':
    plt.rc('font', family='Malgun Gothic')

# %%
from matplotlib import pyplot as plt
 
plt.plot(["유흥시설\n(6)","신천지\n(9)","조사중\n(12)","그외 기타\n(21)","해외유입\n(40))","집단발병\n(174)"], [2.3,3.4,4.6,12,15.3,66.4])
plt.xlabel('소재\n(명)')
plt.ylabel('비율(%)')
plt.title('광주 소재별 확진자 현황\n(질병관리본부 2020-08-22 집계기준)')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os
os.name
if os.name == 'nt':
    plt.rc('font', family='Malgun Gothic')

# %%
from matplotlib import pyplot as plt
 
plt.plot(["교회\n(17)","조사중\n(130)","요양원\n(134)","집단발병\n(264)","그외 기타\n(539)","신천지\n(566)"], [0.5,9.1,9.3,18.4,23.3,39.4])
plt.xlabel('소재\n(명)')
plt.ylabel('비율(%)')
plt.title('경북 소재별 확진자 현황\n(질병관리본부 2020-08-22 집계기준)')
plt.show()
